# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('house_prices.csv')

# %%
X = df.drop(columns=['Price','Location'])
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test,y_pred)
print("Mean Squred Error :",mse)
# Out:
# Mean Squred Error : 229029603.57416326

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn.metrics import accuracy_score

model.predict(X_test)
# Out:
# array([438004.90303734, 428048.03283156, 447961.77324312, 408134.29242   ,
#        367965.78193259, 428048.03283156, 358008.91172681, 447961.77324312,
#        348052.04152103, 418091.16262578, 297926.66082783, 418091.16262578,
#        358008.91172681, 358008.91172681, 438004.90303734, 367965.78193259,
#        367965.78193259, 358008.91172681, 338095.17131525, 358008.91172681])

# %%
y_test
# Out:
# 88    450000
# 55    420000
# 13    420000
# 18    400000
# 31    380000
# 91    430000
# 57    360000
# 23    430000
# 3     350000
# 24    390000
# 7     280000
# 14    395000
# 16    375000
# 6     370000
# 52    430000
# 90    380000
# 72    380000
# 66    370000
# 5     320000
# 93    370000
# Name: Price, dtype: int64

# %%
import joblib
joblib.dump(model,'house_price_prediction.pkl')
# Out:
# ['house_price_prediction.pkl']
